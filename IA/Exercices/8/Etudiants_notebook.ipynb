# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt

import skimage as sk
import skimage.io as skio
from skimage.transform import resize

# %%
# On importe l'image originale ex: lions.jpg
filename = 'lions.jpg'
# VOTRE PATH
dirpath = ''

# TODO

plt.figure()
plt.imshow(img)
plt.title("image originale")
plt.show()
# Out:
# /content/drive/MyDrive/PhD/Activities/Enseignements/Fabron DUT2 - Introduction IA/TP8/lions.jpg
# Loaded image has dimensions: (1280, 1920, 3)

# %%
# On récupere les paths de tous les patches (700 images)
# TODO
len(listP)
# 700

# %%
#definition de la taille des patches
# TODO

N=# TODO
M=# TODO
print(N); print(M)

# %%
#On créer une matrice NxMx3 où chaque valeur correspond à la valeur moyenne du block
# TODO
        
plt.figure()
plt.imshow(m_mat/255)
plt.show()

# %%
# On calcule la moyenne des valeurs RGB de chaque patche
# TODO

# %%
#Research of the best coresponding patch image
M_recomb=np.zeros((N,M))
# On parcourt tous les pixels
for i in range(N):
    for j in range(M):
        # TODO

# %%
#Recombination of the final image
IMG_Recomb=np.zeros((N*block_x,M*block_y,3))
for i in range(N):
        for j in range(M):
            # TODO
        
IMG=IMG_Recomb.astype(int)
plt.figure()
plt.imshow(IMG)
plt.title("mosaic image with block size: 15x15")
plt.show()
